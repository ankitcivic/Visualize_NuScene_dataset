# %%
#import libraries
import random, os, cv2
from IPython.display import Image 

#defining path of images
path = r"/home/ankit/Perception/HW1/data/sets/nuscenes/samples/CAM_FRONT"

#selecting a random file
random_file = random.choice([
    x for x in os.listdir(path)
    if os.path.isfile(os.path.join(path, x))
])

#printing random file name
print('image being displayed is', random_file)

#displaying random file
image_path = cv2.imread('/home/ankit/Perception/HW1/data/sets/nuscenes/samples/CAM_FRONT/')

random_selected_file = (os.path.join(path, random_file)) 

Image(filename=random_selected_file)
# Out:
# image being displayed is n015-2018-11-21-19-38-26+0800__CAM_FRONT__1542800859412460.jpg
